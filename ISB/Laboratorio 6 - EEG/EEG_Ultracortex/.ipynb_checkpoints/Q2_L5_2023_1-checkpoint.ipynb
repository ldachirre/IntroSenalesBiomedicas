# %% [markdown]
# # Question 1 (5.0 pts)
#
# Given the sequence of a discrete function  you are ask to prove if the DFT of the sequence using FFT command is equivalent to the different algorithms to obtain an efficient calculation to reduce the computational cost.
#
# $$x_1 \left\lbrack n\right\rbrack ={\left(\frac{8}{5}\right)}^n \left(u\left\lbrack n\right\rbrack -u\left\lbrack n-9\right\rbrack \right)+{\left(\frac{3}{8}\right)}^n \left(u\left\lbrack n\right\rbrack -u\left\lbrack n-3\right\rbrack \right)$$
#
#
#
# a) (0.25 pt) Plot the present sequence with the number of samples N=10 to obtain a visual and fast inspection of its components. Use appropiate labels.
#
# b) (2.0 pt) Find the DFT of the sequence using "Divide and Conquer Method" with the next partition of elements of L=5 and M=2.
#
# c) (1.25 pt) What is the ratio between the complex multiplications (CM) and complex sums (CS) using this method? Remember that: $Ratio=\frac{CM}{CS}$
#
# d) (1.5 pt) Use the "fft" command to find the DFT of the same sequence $x_1 \left\lbrack n\right\rbrack$. How can we see, mathematically, if both methods are the same? Hint: Consider that if the error   both methods are similar.

# %% [markdown]
# #Question 2 (10.0 pts)
#
# Given the input signal  corresponding to a discrete finite irregular pulse and the file 'Q2k.mat'  which have the DFT of a second sequence , find the following:
#
#
# <h3><center>Figure N°1: Signal </center></h3>
#
# a) (1.0 pt) Find the inverse DFT for the **'Q2k.mat'** signal. This signal will be associated to ${\mathrm{q}}_2 {\left\lbrack n\right\rbrack }_{\mathrm{test}}$. Plot the signal  with the appropiate labels.
#
# b) (2.0 pt) Find the coefficients and values of the expression that allow you to build $q_2 \left\lbrack n\right\rbrack =aq_1 \left\lbrack n\right\rbrack -b{q_1 \left\lbrack n-l\right\rbrack }_n$  from $q_1 \left\lbrack n\right\rbrack$, where $\mathit{\mathbf{a}}=\mathit{\mathbf{l}}$ and $\mathit{\mathbf{b}}=\frac{1}{\mathit{\mathbf{a}}}$.
#
# **Hint:** The value of  $0<a<10$
#
# c) (1.0 pt)** Compute** $q_2 \left\lbrack n\right\rbrack$ from the expression found in the previous step. Display the norm of the difference between $q_2 \left\lbrack n\right\rbrack$ compute in this step and $q_2 \left\lbrack n\right\rbrack$ found through the inverse DFT from the previous step.
#
# d) (1.0 pt) Find the expression that relates $Q_1 \left\lbrack k\right\rbrack$ for $Q_2 \left\lbrack k\right\rbrack$ and **compute** the DFT of $Q_2 \left\lbrack k\right\rbrack$ from the DFT of $Q_1 \left\lbrack k\right\rbrack$ .
#
# e) (1.0 pt) Validate yout procedure with the given file. Display the **norm** of the difference bewteen $Q_2 \left\lbrack k\right\rbrack$  and $Q_2 {\left\lbrack k\right\rbrack }_{\mathrm{test}}$ .
#
# Now, you have the next blocks diagram which includes a big system and it's output $y\left\lbrack n\right\rbrack$. You have to find the **coefficients** for the different **shifted inputs** of a new signal . The problem for achieve the solution is that you have file **'Yk.mat'** that includes the DFT of $y\left\lbrack n\right\rbrack$.Follow the instructions:
#
# ![Diagram block.png](data:image/png;base64,...)
#
# f) (1.5 pt) How can you find $a_0 ,a_{1\;} ,a_2 ,a_3 \;\mathrm{and}\;a_4$ from **'Yk.mat'** ?. Propose a solution for the preset problem which must include an explanation of yout approach. Remember that you have to work with the Discrete Fourier Transform concepts.
#
# g) (2.5 pt)  Recover the coefficients $a_0 ,a_{1\;} ,a_2 ,a_3 \;\mathrm{and}\;a_4$ from **'Yk.mat'**  using your approach mention in the previous step.
