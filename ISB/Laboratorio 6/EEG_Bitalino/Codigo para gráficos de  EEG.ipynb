# %% [markdown]
# # Laboratorio 6 EKG

# %% [markdown]
# ### S1 Reposo 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# Nombre de tu archivo TXT
archivo_txt = "EEG30s.txt"

# Cargar los datos desde el archivo TXT
datos_emg = np.loadtxt(archivo_txt)

# Extraer la sexta columna de datos_emg
# recordamos que el archivo txt me da informacion de todas las entradas del bitalino pero 
# la única que nos interesa es la que se encuentra en el encabezado A1
columna_sexta = datos_emg[:, 5]  # El índice 5 representa la sexta columna (0-indexed)

# Crear un arreglo de tiempo en segundos
frecuencia_muestreo = 1000  # Frecuencia de muestreo en Hz
tiempo = np.arange(len(columna_sexta)) / frecuencia_muestreo

# Definir el intervalo de tiempo que deseas graficar (segundos 6 al 7)
inicio_segundo = 24
fin_segundo = 31
inicio_muestra = int(inicio_segundo * frecuencia_muestreo)
fin_muestra = int(fin_segundo * frecuencia_muestreo)

# Extraer los datos del intervalo de tiempo especificado
tiempo_intervalo = tiempo[inicio_muestra:fin_muestra]
columna_intervalo = columna_sexta[inicio_muestra:fin_muestra]

# Crear el gráfico
plt.figure(figsize=(20, 4))  # Ajusta el tamaño del gráfico según tus necesidades
plt.plot(tiempo, columna_sexta, lw=1, color='blue')
plt.xlabel('Tiempo (s)')
plt.ylabel('Valor EEG ')
plt.title('Datos de EEG  (S1 Reposo 30s)')
plt.grid(True)

# Mostrar el gráfico
plt.show()


# Crear el gráfico para los datos del intervalo de tiempo especificado
#esto nos permite visualizar de mejor manera los datos
plt.figure(figsize=(10, 4))  # Ajusta el tamaño del gráfico según tus necesidades
plt.plot(tiempo_intervalo, columna_intervalo, lw=1, color='blue')
plt.xlabel('Tiempo (s)')
plt.ylabel('Valor EEG')
plt.title('Datos de EEG Ampliados en Reposo 30s (Segundos 24 al 31)')
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Sujeto 1 Parpadeando

# %%
import numpy as np
import matplotlib.pyplot as plt

# Nombre de tu archivo TXT
archivo_txt = "EEGparpadeo.txt"

# Cargar los datos desde el archivo TXT
datos_emg = np.loadtxt(archivo_txt)

# Extraer la sexta columna de datos_emg
# recordamos que el archivo txt me da informacion de todas las entradas del bitalino pero 
# la única que nos interesa es la que se encuentra en el encabezado A1
columna_sexta = datos_emg[:, 5]  # El índice 5 representa la sexta columna (0-indexed)

# Crear un arreglo de tiempo en segundos
frecuencia_muestreo = 1000  # Frecuencia de muestreo en Hz
tiempo = np.arange(len(columna_sexta)) / frecuencia_muestreo

# Definir el intervalo de tiempo que deseas graficar (segundos 6 al 7)
inicio_segundo = 26
fin_segundo = 33
inicio_muestra = int(inicio_segundo * frecuencia_muestreo)
fin_muestra = int(fin_segundo * frecuencia_muestreo)

# Extraer los datos del intervalo de tiempo especificado
tiempo_intervalo = tiempo[inicio_muestra:fin_muestra]
columna_intervalo = columna_sexta[inicio_muestra:fin_muestra]

# Crear el gráfico
plt.figure(figsize=(20, 4))  # Ajusta el tamaño del gráfico según tus necesidades
plt.plot(tiempo, columna_sexta, lw=1, color='blue')
plt.xlabel('Tiempo (s)')
plt.ylabel('Valor EEG ')
plt.title('Datos de EEG  (S1 Parpadeo)')
plt.grid(True)

# Mostrar el gráfico
plt.show()


# Crear el gráfico para los datos del intervalo de tiempo especificado
#esto nos permite visualizar de mejor manera los datos
plt.figure(figsize=(10, 4))  # Ajusta el tamaño del gráfico según tus necesidades
plt.plot(tiempo_intervalo, columna_intervalo, lw=1, color='blue')
plt.xlabel('Tiempo (s)')
plt.ylabel('Valor EEG')
plt.title('Datos de EEG Ampliados en un parpadeo (Segundos 26 al 33)')
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### S1 Reposo 2

# %%
# Nombre de tu archivo TXT
archivo_txt = "EEG30s2.txt"

# Cargar los datos desde el archivo TXT
datos_emg = np.loadtxt(archivo_txt)

# Extraer la sexta columna de datos_emg
# recordamos que el archivo txt me da informacion de todas las entradas del bitalino pero 
# la única que nos interesa es la que se encuentra en el encabezado A1
columna_sexta = datos_emg[:, 5]  # El índice 5 representa la sexta columna (0-indexed)

# Crear un arreglo de tiempo en segundos
frecuencia_muestreo = 1000  # Frecuencia de muestreo en Hz
tiempo = np.arange(len(columna_sexta)) / frecuencia_muestreo

# Definir el intervalo de tiempo que deseas graficar (segundos 6 al 7)
inicio_segundo = 24
fin_segundo = 31
inicio_muestra = int(inicio_segundo * frecuencia_muestreo)
fin_muestra = int(fin_segundo * frecuencia_muestreo)

# Extraer los datos del intervalo de tiempo especificado
tiempo_intervalo = tiempo[inicio_muestra:fin_muestra]
columna_intervalo = columna_sexta[inicio_muestra:fin_muestra]

# Crear el gráfico
plt.figure(figsize=(20, 4))  # Ajusta el tamaño del gráfico según tus necesidades
plt.plot(tiempo, columna_sexta, lw=1, color='blue')
plt.xlabel('Tiempo (s)')
plt.ylabel('Valor EEG ')
plt.title('Datos de EEG  (S1 Reposo2 30s)')
plt.grid(True)

# Mostrar el gráfico
plt.show()


# Crear el gráfico para los datos del intervalo de tiempo especificado
#esto nos permite visualizar de mejor manera los datos
plt.figure(figsize=(10, 4))  # Ajusta el tamaño del gráfico según tus necesidades
plt.plot(tiempo_intervalo, columna_intervalo, lw=1, color='blue')
plt.xlabel('Tiempo (s)')
plt.ylabel('Valor EEG')
plt.title('Datos de EEG Ampliados en Segundo Reposo 30s (Segundos 24 al 31)')
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### EEG de Sujeto 1 cuando le hacen preguntas fáciles

# %%
import numpy as np
import matplotlib.pyplot as plt

# Nombre de tu archivo TXT
archivo_txt = "EEG_preguntas_faciles.txt"

# Cargar los datos desde el archivo TXT
datos_emg = np.loadtxt(archivo_txt)

# Extraer la sexta columna de datos_emg
# recordamos que el archivo txt me da informacion de todas las entradas del bitalino pero 
# la única que nos interesa es la que se encuentra en el encabezado A1
columna_sexta = datos_emg[:, 5]  # El índice 5 representa la sexta columna (0-indexed)

# Crear un arreglo de tiempo en segundos
frecuencia_muestreo = 1000  # Frecuencia de muestreo en Hz
tiempo = np.arange(len(columna_sexta)) / frecuencia_muestreo

# Definir el intervalo de tiempo que deseas graficar (segundos 6 al 7)
inicio_segundo = 26
fin_segundo = 33
inicio_muestra = int(inicio_segundo * frecuencia_muestreo)
fin_muestra = int(fin_segundo * frecuencia_muestreo)

# Extraer los datos del intervalo de tiempo especificado
tiempo_intervalo = tiempo[inicio_muestra:fin_muestra]
columna_intervalo = columna_sexta[inicio_muestra:fin_muestra]

# Crear el gráfico
plt.figure(figsize=(20, 4))  # Ajusta el tamaño del gráfico según tus necesidades
plt.plot(tiempo, columna_sexta, lw=1, color='blue')
plt.xlabel('Tiempo (s)')
plt.ylabel('Valor EEG ')
plt.title('Datos de EEG  (S1 cuando le hacen preguntas fáciles)')
plt.grid(True)

# Mostrar el gráfico
plt.show()


# Crear el gráfico para los datos del intervalo de tiempo especificado
#esto nos permite visualizar de mejor manera los datos
plt.figure(figsize=(10, 4))  # Ajusta el tamaño del gráfico según tus necesidades
plt.plot(tiempo_intervalo, columna_intervalo, lw=1, color='blue')
plt.xlabel('Tiempo (s)')
plt.ylabel('Valor EEG')
plt.title('Datos de EEG Ampliados (S1 cuando le hacen preguntas fáciles)')
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### EEG de Sujeto 1 cuando le hacen preguntas difíciles

# %%
import numpy as np
import matplotlib.pyplot as plt

# Nombre de tu archivo TXT
archivo_txt = "EEG_preguntas_dificiles.txt"

# Cargar los datos desde el archivo TXT
datos_emg = np.loadtxt(archivo_txt)

# Extraer la sexta columna de datos_emg
# recordamos que el archivo txt me da informacion de todas las entradas del bitalino pero 
# la única que nos interesa es la que se encuentra en el encabezado A1
columna_sexta = datos_emg[:, 5]  # El índice 5 representa la sexta columna (0-indexed)

# Crear un arreglo de tiempo en segundos
frecuencia_muestreo = 1000  # Frecuencia de muestreo en Hz
tiempo = np.arange(len(columna_sexta)) / frecuencia_muestreo

# Definir el intervalo de tiempo que deseas graficar (segundos 6 al 7)
inicio_segundo = 26
fin_segundo = 33
inicio_muestra = int(inicio_segundo * frecuencia_muestreo)
fin_muestra = int(fin_segundo * frecuencia_muestreo)

# Extraer los datos del intervalo de tiempo especificado
tiempo_intervalo = tiempo[inicio_muestra:fin_muestra]
columna_intervalo = columna_sexta[inicio_muestra:fin_muestra]

# Crear el gráfico
plt.figure(figsize=(20, 4))  # Ajusta el tamaño del gráfico según tus necesidades
plt.plot(tiempo, columna_sexta, lw=1, color='blue')
plt.xlabel('Tiempo (s)')
plt.ylabel('Valor EEG ')
plt.title('Datos de EEG  (S1 cuando le hacen preguntas difíciles)')
plt.grid(True)

# Mostrar el gráfico
plt.show()


# Crear el gráfico para los datos del intervalo de tiempo especificado
#esto nos permite visualizar de mejor manera los datos
plt.figure(figsize=(10, 4))  # Ajusta el tamaño del gráfico según tus necesidades
plt.plot(tiempo_intervalo, columna_intervalo, lw=1, color='blue')
plt.xlabel('Tiempo (s)')
plt.ylabel('Valor EEG')
plt.title('Datos de EEG Ampliados (S1 cuando le hacen preguntas difíciles)')
plt.grid(True)

# Mostrar el gráfico
plt.show()
