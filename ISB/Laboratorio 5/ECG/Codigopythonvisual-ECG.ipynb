# %% [markdown]
# # Laboratorio 5 EKG

# %% [markdown]
# ### Sujeto 1 en Reposo

# %%
import numpy as np
import matplotlib.pyplot as plt

# Nombre de tu archivo TXT
archivo_txt = "S1relajado.txt"

# Cargar los datos desde el archivo TXT
datos_emg = np.loadtxt(archivo_txt)

# Extraer la sexta columna de datos_emg
# recordamos que el archivo txt me da informacion de todas las entradas del bitalino pero 
# la única que nos interesa es la que se encuentra en el encabezado A1
columna_sexta = datos_emg[:, 5]  # El índice 5 representa la sexta columna (0-indexed)

# Crear un arreglo de tiempo en segundos
frecuencia_muestreo = 1000  # Frecuencia de muestreo en Hz
tiempo = np.arange(len(columna_sexta)) / frecuencia_muestreo

# Definir el intervalo de tiempo que deseas graficar (segundos 6 al 7)
inicio_segundo = 6
fin_segundo = 8
inicio_muestra = int(inicio_segundo * frecuencia_muestreo)
fin_muestra = int(fin_segundo * frecuencia_muestreo)

# Extraer los datos del intervalo de tiempo especificado
tiempo_intervalo = tiempo[inicio_muestra:fin_muestra]
columna_intervalo = columna_sexta[inicio_muestra:fin_muestra]

# Crear el gráfico
plt.figure(figsize=(10, 4))  # Ajusta el tamaño del gráfico según tus necesidades
plt.plot(tiempo, columna_sexta, lw=1, color='blue')
plt.xlabel('Tiempo (s)')
plt.ylabel('Valor ECG ')
plt.title('Datos de ECG  (S1 Relajado)')
plt.grid(True)

# Mostrar el gráfico
plt.show()


# Crear el gráfico para los datos del intervalo de tiempo especificado
#esto nos permite visualizar de mejor manera los datos
plt.figure(figsize=(10, 4))  # Ajusta el tamaño del gráfico según tus necesidades
plt.plot(tiempo_intervalo, columna_intervalo, lw=1, color='blue')
plt.xlabel('Tiempo (s)')
plt.ylabel('Valor ECG')
plt.title('Datos de ECG Ampliados S1 (Segundos 6 al 8)')
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Sujeto 1 Activo

# %%
import numpy as np
import matplotlib.pyplot as plt

# Nombre de tu archivo TXT
archivo_txt = "S1activo.txt"

# Cargar los datos desde el archivo TXT
datos_emg = np.loadtxt(archivo_txt)

# Extraer la sexta columna de datos_emg
# recordamos que el archivo txt me da informacion de todas las entradas del bitalino pero 
# la única que nos interesa es la que se encuentra en el encabezado A1
columna_sexta = datos_emg[:, 5]  # El índice 5 representa la sexta columna (0-indexed)

# Crear un arreglo de tiempo en segundos
frecuencia_muestreo = 1000  # Frecuencia de muestreo en Hz
tiempo = np.arange(len(columna_sexta)) / frecuencia_muestreo

# Definir el intervalo de tiempo que deseas graficar (segundos 6 al 7)
inicio_segundo = 5.5
fin_segundo = 8
inicio_muestra = int(inicio_segundo * frecuencia_muestreo)
fin_muestra = int(fin_segundo * frecuencia_muestreo)

# Extraer los datos del intervalo de tiempo especificado
tiempo_intervalo = tiempo[inicio_muestra:fin_muestra]
columna_intervalo = columna_sexta[inicio_muestra:fin_muestra]

# Crear el gráfico
plt.figure(figsize=(10, 4))  # Ajusta el tamaño del gráfico según tus necesidades
plt.plot(tiempo, columna_sexta, lw=1, color='blue')
plt.xlabel('Tiempo (s)')
plt.ylabel('Valor ECG ')
plt.title('Datos de ECG (S1 Activo)')
plt.grid(True)

# Mostrar el gráfico
plt.show()


# Crear el gráfico para los datos del intervalo de tiempo especificado
#esto nos permite visualizar de mejor manera los datos
plt.figure(figsize=(10, 4))  # Ajusta el tamaño del gráfico según tus necesidades
plt.plot(tiempo_intervalo, columna_intervalo, lw=1, color='blue')
plt.xlabel('Tiempo (s)')
plt.ylabel('Valor ECG')
plt.title('Datos de ECG Ampliados S1 (Segundos 5.5 al 8)')
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### S2 relajado

# %%
import numpy as np
import matplotlib.pyplot as plt

# Nombre de tu archivo TXT
archivo_txt = "S2relajado.txt"

# Cargar los datos desde el archivo TXT
datos_emg = np.loadtxt(archivo_txt)

# Extraer la sexta columna de datos_emg
# recordamos que el archivo txt me da informacion de todas las entradas del bitalino pero 
# la única que nos interesa es la que se encuentra en el encabezado A1
columna_sexta = datos_emg[:, 5]  # El índice 5 representa la sexta columna (0-indexed)

# Crear un arreglo de tiempo en segundos
frecuencia_muestreo = 1000  # Frecuencia de muestreo en Hz
tiempo = np.arange(len(columna_sexta)) / frecuencia_muestreo

# Definir el intervalo de tiempo que deseas graficar (segundos 6 al 7)
inicio_segundo = 6
fin_segundo = 8
inicio_muestra = int(inicio_segundo * frecuencia_muestreo)
fin_muestra = int(fin_segundo * frecuencia_muestreo)

# Extraer los datos del intervalo de tiempo especificado
tiempo_intervalo = tiempo[inicio_muestra:fin_muestra]
columna_intervalo = columna_sexta[inicio_muestra:fin_muestra]

# Crear el gráfico
plt.figure(figsize=(10, 4))  # Ajusta el tamaño del gráfico según tus necesidades
plt.plot(tiempo, columna_sexta, lw=1, color='blue')
plt.xlabel('Tiempo (s)')
plt.ylabel('Valor ECG ')
plt.title('Datos de ECG (S2 Relajado)')
plt.grid(True)

# Mostrar el gráfico
plt.show()


# Crear el gráfico para los datos del intervalo de tiempo especificado
#esto nos permite visualizar de mejor manera los datos
plt.figure(figsize=(10, 4))  # Ajusta el tamaño del gráfico según tus necesidades
plt.plot(tiempo_intervalo, columna_intervalo, lw=1, color='blue')
plt.xlabel('Tiempo (s)')
plt.ylabel('Valor ECG')
plt.title('Datos de ECG Ampliados  S2 (Segundos 6 al 8)')
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### S2 activo

# %%
import numpy as np
import matplotlib.pyplot as plt

# Nombre de tu archivo TXT
archivo_txt = "S2acrivo.txt"

# Cargar los datos desde el archivo TXT
datos_emg = np.loadtxt(archivo_txt)

# Extraer la sexta columna de datos_emg
# recordamos que el archivo txt me da informacion de todas las entradas del bitalino pero 
# la única que nos interesa es la que se encuentra en el encabezado A1
columna_sexta = datos_emg[:, 5]  # El índice 5 representa la sexta columna (0-indexed)

# Crear un arreglo de tiempo en segundos
frecuencia_muestreo = 1000  # Frecuencia de muestreo en Hz
tiempo = np.arange(len(columna_sexta)) / frecuencia_muestreo

# Definir el intervalo de tiempo que deseas graficar (segundos 6 al 7)
inicio_segundo = 6
fin_segundo = 8
inicio_muestra = int(inicio_segundo * frecuencia_muestreo)
fin_muestra = int(fin_segundo * frecuencia_muestreo)

# Extraer los datos del intervalo de tiempo especificado
tiempo_intervalo = tiempo[inicio_muestra:fin_muestra]
columna_intervalo = columna_sexta[inicio_muestra:fin_muestra]

# Crear el gráfico
plt.figure(figsize=(10, 4))  # Ajusta el tamaño del gráfico según tus necesidades
plt.plot(tiempo, columna_sexta, lw=1, color='blue')
plt.xlabel('Tiempo (s)')
plt.ylabel('Valor ECG ')
plt.title('Datos de ECG (S2 Activo)')
plt.grid(True)

# Mostrar el gráfico
plt.show()


# Crear el gráfico para los datos del intervalo de tiempo especificado
#esto nos permite visualizar de mejor manera los datos
plt.figure(figsize=(10, 4))  # Ajusta el tamaño del gráfico según tus necesidades
plt.plot(tiempo_intervalo, columna_intervalo, lw=1, color='blue')
plt.xlabel('Tiempo (s)')
plt.ylabel('Valor ECG')
plt.title('Datos de ECG S2  Ampliados(Segundos 6 al 8)')
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Sujeto 3 en repososo

# %%
import numpy as np
import matplotlib.pyplot as plt

# Nombre de tu archivo TXT
archivo_txt = "S3relajadocorregido.txt"

# Cargar los datos desde el archivo TXT
datos_emg = np.loadtxt(archivo_txt)

# Extraer la sexta columna de datos_emg
# recordamos que el archivo txt me da informacion de todas las entradas del bitalino pero 
# la única que nos interesa es la que se encuentra en el encabezado A1
columna_sexta = datos_emg[:, 5]  # El índice 5 representa la sexta columna (0-indexed)

# Crear un arreglo de tiempo en segundos
frecuencia_muestreo = 1000  # Frecuencia de muestreo en Hz
tiempo = np.arange(len(columna_sexta)) / frecuencia_muestreo

# Definir el intervalo de tiempo que deseas graficar (segundos 6 al 7)
inicio_segundo = 20
fin_segundo = 23
inicio_muestra = int(inicio_segundo * frecuencia_muestreo)
fin_muestra = int(fin_segundo * frecuencia_muestreo)

# Extraer los datos del intervalo de tiempo especificado
tiempo_intervalo = tiempo[inicio_muestra:fin_muestra]
columna_intervalo = columna_sexta[inicio_muestra:fin_muestra]

# Crear el gráfico
plt.figure(figsize=(10, 4))  # Ajusta el tamaño del gráfico según tus necesidades
plt.plot(tiempo, columna_sexta, lw=1, color='blue')
plt.xlabel('Tiempo (s)')
plt.ylabel('Valor ECG ')
plt.title('Datos de ECG S3 Relajado')
plt.grid(True)

# Mostrar el gráfico
plt.show()


# Crear el gráfico para los datos del intervalo de tiempo especificado
plt.figure(figsize=(10, 4))  # Ajusta el tamaño del gráfico según tus necesidades
plt.plot(tiempo_intervalo, columna_intervalo, lw=1, color='blue')
plt.xlabel('Tiempo (s)')
plt.ylabel('Valor ECG ')
plt.title('Datos  de ECG Ampliación de ECG S3')
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Sujeto 3 activo

# %%
import numpy as np
import matplotlib.pyplot as plt

# Nombre de tu archivo TXT
archivo_txt = "S3activocorregido.txt"

# Cargar los datos desde el archivo TXT
datos_emg = np.loadtxt(archivo_txt)

# Extraer la sexta columna de datos_emg
# recordamos que el archivo txt me da informacion de todas las entradas del bitalino pero 
# la única que nos interesa es la que se encuentra en el encabezado A1
columna_sexta = datos_emg[:, 5]  # El índice 5 representa la sexta columna (0-indexed)

# Crear un arreglo de tiempo en segundos
frecuencia_muestreo = 1000  # Frecuencia de muestreo en Hz
tiempo = np.arange(len(columna_sexta)) / frecuencia_muestreo

# Definir el intervalo de tiempo que deseas graficar (segundos 6 al 7)
inicio_segundo = 20
fin_segundo = 23
inicio_muestra = int(inicio_segundo * frecuencia_muestreo)
fin_muestra = int(fin_segundo * frecuencia_muestreo)

# Extraer los datos del intervalo de tiempo especificado
tiempo_intervalo = tiempo[inicio_muestra:fin_muestra]
columna_intervalo = columna_sexta[inicio_muestra:fin_muestra]

# Crear el gráfico
plt.figure(figsize=(10, 4))  # Ajusta el tamaño del gráfico según tus necesidades
plt.plot(tiempo, columna_sexta, lw=1, color='blue')
plt.xlabel('Tiempo (s)')
plt.ylabel('Valor ECG ')
plt.title('Datos de ECG (S3 Activo)')
plt.grid(True)

# Mostrar el gráfico
plt.show()


# Crear el gráfico para los datos del intervalo de tiempo especificado
#esto nos permite visualizar de mejor manera los datos
plt.figure(figsize=(10, 4))  # Ajusta el tamaño del gráfico según tus necesidades
plt.plot(tiempo_intervalo, columna_intervalo, lw=1, color='blue')
plt.xlabel('Tiempo (s)')
plt.ylabel('Valor ECG')
plt.title('Datos de ECG  Ampliación S3 (Segundos 20 al 23)')
plt.grid(True)

# Mostrar el gráfico
plt.show()
